# %%
import pandas as pd

# %%
df = pd.read_excel('Xiyouji_Masterfile_20220103_HYJ tags.xlsx')
df
# Out:
#       title     n            chaptitle  \
# 0       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# 1       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# 2       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# 3       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# 4       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# ...     ...   ...                  ...
# 24341   西遊記  第一百回       第一百回　徑回東土　五聖成真
# 24342   西遊記  第一百回       第一百回　徑回東土　五聖成真
# 24343   西遊記  第一百回       第一百回　徑回東土　五聖成真
# 24344   西遊記  第一百回       第一百回　徑回東土　五聖成真
# 24345   西遊記  第一百回       第一百回　徑回東土　五聖成真
#
#                                                        s     sn SOURCE TARGET  \
# 0                                    詩曰：混沌未分天地亂，茫茫渺渺無人見。      1    NaN    NaN
# 1                                       自從盤古破鴻濛，開闢從茲清濁辨。      2    NaN    NaN
# 2                                       覆載群生仰至仁，發明萬物皆成善。      3    NaN    NaN
# 3                                       欲知造化會元功，須看西遊釋厄傳。      4    NaN    NaN
# 4                                   蓋聞天地之數，有十二萬九千六百歲為一元。      5    NaN    NaN
# ...                                                  ...    ...    ...    ...
# 24341                                   五色梅時開時結，萬年桃時熟時新。  23296    NaN    NaN
# 24342                                     千果千花爭秀，一天瑞靄紛紜。  23297    NaN    NaN
# 24343                                            大眾合掌皈依。  23298    NaN    NaN
# 24344  都念：「南無燃燈上古佛。南無藥師琉璃光王佛。南無釋迦牟尼佛。南無過去未來現在佛。南無清淨喜佛...  23299    NaN    NaN
# 24345                                          「西遊記」至此終。  23300    NaN    NaN
#
#       ACTION  P/N COMMENTS QUESTIONS?  Unnamed: 11
# 0        NaN  NaN      NaN        NaN          NaN
# 1        NaN  NaN      NaN        NaN          NaN
# 2        NaN  NaN      NaN        NaN          NaN
# 3        NaN  NaN      NaN        NaN          NaN
# 4        NaN  NaN      NaN        NaN          NaN
# ...      ...  ...      ...        ...          ...
# 24341    NaN  NaN      NaN        NaN          NaN
# 24342    NaN  NaN      NaN        NaN          NaN
# 24343    NaN  NaN      NaN        NaN          NaN
# 24344    NaN  NaN      NaN        NaN          NaN
# 24345    NaN  NaN      NaN        NaN          NaN
#
# [24346 rows x 12 columns]

# %%
df.drop('Unnamed: 11', axis=1, inplace=True)

# %%
df = df.loc[:, ['s', 'SOURCE', 'TARGET', 'ACTION', 'P/N']]

# %%
df['SOURCE'] = df['SOURCE'].apply(lambda x: '' if pd.isna(x) else x)

# %%
df['TARGET'] = df['TARGET'].apply(lambda x: '' if pd.isna(x) else x)

# %%
df['ACTION'] = df['ACTION'].apply(lambda x: '' if pd.isna(x) else x)

# %%
df
# Out:
#                                                        s SOURCE TARGET ACTION  \
# 0                                    詩曰：混沌未分天地亂，茫茫渺渺無人見。
# 1                                       自從盤古破鴻濛，開闢從茲清濁辨。
# 2                                       覆載群生仰至仁，發明萬物皆成善。
# 3                                       欲知造化會元功，須看西遊釋厄傳。
# 4                                   蓋聞天地之數，有十二萬九千六百歲為一元。
# ...                                                  ...    ...    ...    ...
# 24341                                   五色梅時開時結，萬年桃時熟時新。
# 24342                                     千果千花爭秀，一天瑞靄紛紜。
# 24343                                            大眾合掌皈依。
# 24344  都念：「南無燃燈上古佛。南無藥師琉璃光王佛。南無釋迦牟尼佛。南無過去未來現在佛。南無清淨喜佛...
# 24345                                          「西遊記」至此終。
#
#        P/N
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 24341  NaN
# 24342  NaN
# 24343  NaN
# 24344  NaN
# 24345  NaN
#
# [24346 rows x 5 columns]

# %%
df_empty = df.loc[(df['SOURCE']=='') & (df['TARGET']=='') & (df['ACTION']=='')]

# %%
df_nonempty = df.loc[(df['SOURCE']!='') & (df['TARGET']!='') & (df['ACTION']!='')]

# %%
df_empty
# Out:
#                                                        s SOURCE TARGET ACTION  \
# 0                                    詩曰：混沌未分天地亂，茫茫渺渺無人見。
# 1                                       自從盤古破鴻濛，開闢從茲清濁辨。
# 2                                       覆載群生仰至仁，發明萬物皆成善。
# 3                                       欲知造化會元功，須看西遊釋厄傳。
# 4                                   蓋聞天地之數，有十二萬九千六百歲為一元。
# ...                                                  ...    ...    ...    ...
# 24341                                   五色梅時開時結，萬年桃時熟時新。
# 24342                                     千果千花爭秀，一天瑞靄紛紜。
# 24343                                            大眾合掌皈依。
# 24344  都念：「南無燃燈上古佛。南無藥師琉璃光王佛。南無釋迦牟尼佛。南無過去未來現在佛。南無清淨喜佛...
# 24345                                          「西遊記」至此終。
#
#        P/N
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 24341  NaN
# 24342  NaN
# 24343  NaN
# 24344  NaN
# 24345  NaN
#
# [15766 rows x 5 columns]

# %%
df_nonempty
# Out:
#                                                        s   SOURCE   TARGET  \
# 56     驚動高天上聖大慈仁者玉皇大天尊玄穹高上帝，駕座金闕雲宮靈霄寶殿，聚集仙卿，見有金光燄燄，即命...     玉皇大帝  千里眼、順風耳
# 59     須臾回報道：「臣奉旨觀聽金光之處，乃東勝神洲海東傲來小國之界，有一座花果山，山上有一仙石，石...  千里眼、順風耳     玉皇大帝
# 60                          玉帝垂賜恩慈曰：「下方之物，乃天地精華所生，不足為異。」     玉皇大帝  千里眼、順風耳
# 76                    連呼了三聲，忽見叢雜中跳出一個石猴，應聲高叫道：「我進去！我進去！」       石猴       眾猴
# 94          石猿喜不自勝，急抽身往外便走，復瞑目蹲身，跳出水外，打了兩個呵呵道：「大造化！大造化！」       石猴       眾猴
# ...                                                  ...      ...      ...
# 12273                                   那魔王把鎗尖點地，喝令小妖齊來。       魔王       小妖
# 12274                       那些潑怪，一個個拿刀弄杖，執劍輪鎗，把個孫大聖圍在中間。       小妖       行者
# 12275                          行者公然不懼，只叫：「來得好！來得好！正合吾意！」       行者       小妖
# 12276                                  使一條金箍棒，前迎後架，東攩西除。       小妖       行者
# 12281                             老魔王唏唏冷笑道：「那猴不要無禮！看手段！」       魔王       行者
#
#        ACTION P/N
# 56     開南天門觀看   P
# 59         回報   P
# 60          曰   P
# 76       應聲高叫   P
# 94          道   P
# ...       ...  ..
# 12273      喝令   P
# 12274       圍   N
# 12275       叫   P
# 12276    前迎後架   N
# 12281     冷笑道   P
#
# [6712 rows x 5 columns]

# %%
from sklearn.utils import resample, shuffle

# %%
df_empty = resample(df_empty, n_samples=10000, random_state=42)

# %%
df_res = pd.concat([df_empty, df_nonempty], axis=0)

# %%
df_res = shuffle(df_res)

# %%
df_res
# Out:
#                                                        s SOURCE TARGET ACTION  \
# 9398   那魔王急回頭，掣出寶刀，高叫道：「孫行者，你好憊𢤿！我來占別人的帝位，與你無干，你怎麼來抱不...     魔王     行者    高叫道
# 15111                               長老躭著勞倦道：「是必掃了，方趁本願。」
# 6383                            行者道：「你不要我做徒弟，只怕你西天路去不成。」     行者     三藏      道
# 5977   唐僧聞言，戰戰兢兢，未曾答應，沙僧掣寶杖，八戒舉釘鈀，大聖使鐵棒，一齊上前，把大仙圍住在空中...     沙僧   鎮元大仙     亂打
# 2487                                        太宗問曰：「此人是誰？」     唐王     崔玨     問曰
# ...                                                  ...    ...    ...    ...
# 521                                      悟空纔按下雲頭，徑闖入朝門裏。
# 21324                行者正與鄧、辛、張、陶，令閃電娘子在空中調弄，只見眾神都到，合會一天。
# 2876   玄奘聞言，心中大喜，翻身跳下臺來，對菩薩起手道：「老師父，弟子失瞻多罪。見前的蓋眾僧人，都講...     玄奘     菩薩      道
# 19808                 卻說行者鬭得心焦性燥，閃一個空，一棍把那妖精打落下來，乃是一隻花鞋。
# 12936                               先生敗了筋力，倒拖著如意鉤，往山上走了。
#
#        P/N
# 9398     N
# 15111  NaN
# 6383     P
# 5977     N
# 2487     P
# ...    ...
# 521    NaN
# 21324  NaN
# 2876     P
# 19808  NaN
# 12936  NaN
#
# [16712 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
df_res['desired_out'] = df_res.apply(lambda x: x['SOURCE']+':'+x['ACTION']+':'+x['TARGET'], axis=1)

# %%
def pn2score(s):
    if s == 'N':
        return -1
    elif s == 'P':
        return 1
    else:
        return 0
df_res['P/N'] = df_res['P/N'].apply(pn2score)

# %%
df_res = df_res.drop(['SOURCE', 'TARGET', 'ACTION'], axis=1).loc[:, ['s', 'desired_out', 'P/N']]

# %%
train, dev_test = train_test_split(df_res, test_size=0.4, train_size=0.6, random_state=42)
dev, test = train_test_split(dev_test, test_size=0.5, train_size=0.5, random_state=42)

# %%
train
# Out:
#                                                        s  desired_out  P/N
# 9715     卻說那怪自把三藏拿到洞中，選剝了衣服，四馬攢蹄，綑在後院裏，著小妖打乾淨水刷洗，要上籠蒸喫哩。   紅孩兒:剝衣服:三藏   -1
# 9473                     行者將菩薩降魔收怪的那一節，陳訴與他君臣聽了，一個個頂禮不盡。   行者:陳訴:君臣儲后    1
# 22107  街衢中有幾個無事閑遊的浪子，見豬八戒嘴長，沙和尚臉黑，孫行者眼紅，都擁擁簇簇的爭看，只是不敢...           ::    0
# 7670                  八戒慌得把個嘴伸出道：「小家形罷了。這不是？你要看便就看，鉤怎的？」      八戒:道:銀角    1
# 19324                         八戒將個死狐狸摜在鹿的面前道：「這可是你的女兒麼？」           ::    0
# ...                                                  ...          ...  ...
# 8077                                      老怪問道：「你是那裏來的？」     女怪:問道:行者    1
# 2485                               太宗道：「寡人空身到此，卻那裏得有錢鈔？」      唐王:道:崔玨    1
# 13958                             師父喫了幾口，定性多時道：「那個去討行李？」           ::    0
# 14165                陰君各執笏，對行者道：「大聖，幽冥處既無名號可查，你還到陽間去折辨。」           ::    0
# 4561                                     八戒指道：「那不是烏巢禪師！」  八戒:指道:三藏、行者    1
#
# [10027 rows x 3 columns]

# %%
dev
# Out:
#                                                        s    desired_out  P/N
# 6789   三藏道：「小僧是唐朝釋子。承我天子敕旨，前往西方取經；原領有文牒，到陛下上國，理合倒換。故此...        三藏:道:國王    1
# 19582                          那道人引定唐僧，直至三層門內看處，比外邊甚是不同。             ::    0
# 18426                                     那繩兒理出去，見風就長粗了。             ::    0
# 19235                                       叫：「八戒，跟我去來。」             ::    0
# 18047          行者暗笑道：「他必是個鋪兵。想是送公文下報帖的。且等我去聽他一聽，看他說些甚話。」             ::    0
# ...                                                  ...            ...  ...
# 20979                          那洞裏大小群妖，一個個魂飛魄散，都報怨先鋒的不是。             ::    0
# 1101   只見那赤腳大仙又頫顖上奏道：「臣蒙王母詔昨日赴會，偶遇齊天大聖，對臣言萬歲有旨，著他邀臣等先...  赤腳大仙:奏道:王母、玉帝    1
# 21979                                           行者聽言，甚喜。             ::    0
# 621                                 眾猴駭然，叫道：「大王！還拿出來耍耍！」      眾猴:叫道:孫悟空    1
# 3342                                      即教媽媽取針線來，遞與行者。        老者:教:媽媽    1
#
# [3342 rows x 3 columns]

# %%
test
# Out:
#                                                        s desired_out  P/N
# 19696  那眾僧道：「直不相瞞老爺說。我這荒山，雖有百十眾和尚，卻都只是自小兒出家的：髮長尋刀削，衣單...          ::    0
# 20349  天王道：「不須囉噪，但依我分擺：孫大聖和太子同領著兵將下去，我們三人在口上把守，做個裏應外合...          ::    0
# 1136                       當時李天王傳了令，著眾天兵扎了營，把那花果山圍得水泄不通。   李天王:著:眾天兵    1
# 18954           行者卻轉身對唐僧道：「師父，此處原是比丘國，今改小子城。但不知改名之意何故也。」          ::    0
# 18269                                   長老道：「這等保不得我過山了？」          ::    0
# ...                                                  ...         ...  ...
# 18026                                   行者道：「不要忙，等我去看看。」          ::    0
# 17375  行者遞與國王道：「此書乃那怪差小校送來者。那小校已先被我打死，送來報功。後復至山中，變作小校...          ::    0
# 5661                          他在那鍋門前，更無心燒火，不時的伸頭探腦，出來觀看。          ::    0
# 8651             僧官道：「你莫胡說！我們老少眾大四五百名和尚，往那裏搬？搬出去，卻也沒處住。」     僧官:道:道人    1
# 18861                         如來道：「我慧眼觀之，故此認得。那老怪與二怪有主。」          ::    0
#
# [3343 rows x 3 columns]

# %%
train.to_csv('./train.csv', index=False)
test.to_csv('./test.csv', index=False)
dev.to_csv('./validate.csv', index=False)
