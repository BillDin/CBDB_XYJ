# %%
import pandas as pd

# %%
df = pd.read_excel('Xiyouji_Masterfile_20220103_HYJ tags.xlsx')
df
# Out:
#       title     n            chaptitle  \
# 0       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# 1       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# 2       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# 3       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# 4       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# ...     ...   ...                  ...
# 24341   西遊記  第一百回       第一百回　徑回東土　五聖成真
# 24342   西遊記  第一百回       第一百回　徑回東土　五聖成真
# 24343   西遊記  第一百回       第一百回　徑回東土　五聖成真
# 24344   西遊記  第一百回       第一百回　徑回東土　五聖成真
# 24345   西遊記  第一百回       第一百回　徑回東土　五聖成真
#
#                                                        s     sn SOURCE TARGET  \
# 0                                    詩曰：混沌未分天地亂，茫茫渺渺無人見。      1    NaN    NaN
# 1                                       自從盤古破鴻濛，開闢從茲清濁辨。      2    NaN    NaN
# 2                                       覆載群生仰至仁，發明萬物皆成善。      3    NaN    NaN
# 3                                       欲知造化會元功，須看西遊釋厄傳。      4    NaN    NaN
# 4                                   蓋聞天地之數，有十二萬九千六百歲為一元。      5    NaN    NaN
# ...                                                  ...    ...    ...    ...
# 24341                                   五色梅時開時結，萬年桃時熟時新。  23296    NaN    NaN
# 24342                                     千果千花爭秀，一天瑞靄紛紜。  23297    NaN    NaN
# 24343                                            大眾合掌皈依。  23298    NaN    NaN
# 24344  都念：「南無燃燈上古佛。南無藥師琉璃光王佛。南無釋迦牟尼佛。南無過去未來現在佛。南無清淨喜佛...  23299    NaN    NaN
# 24345                                          「西遊記」至此終。  23300    NaN    NaN
#
#       ACTION  P/N COMMENTS QUESTIONS?  Unnamed: 11
# 0        NaN  NaN      NaN        NaN          NaN
# 1        NaN  NaN      NaN        NaN          NaN
# 2        NaN  NaN      NaN        NaN          NaN
# 3        NaN  NaN      NaN        NaN          NaN
# 4        NaN  NaN      NaN        NaN          NaN
# ...      ...  ...      ...        ...          ...
# 24341    NaN  NaN      NaN        NaN          NaN
# 24342    NaN  NaN      NaN        NaN          NaN
# 24343    NaN  NaN      NaN        NaN          NaN
# 24344    NaN  NaN      NaN        NaN          NaN
# 24345    NaN  NaN      NaN        NaN          NaN
#
# [24346 rows x 12 columns]

# %%
df.drop('Unnamed: 11', axis=1, inplace=True)

# %%
df = df.loc[:, ['s', 'SOURCE', 'TARGET', 'ACTION', 'P/N']]

# %%
df['SOURCE'] = df['SOURCE'].apply(lambda x: '' if pd.isna(x) else x)

# %%
df['TARGET'] = df['TARGET'].apply(lambda x: '' if pd.isna(x) else x)

# %%
df['ACTION'] = df['ACTION'].apply(lambda x: '' if pd.isna(x) else x)

# %%
df
# Out:
#                                                        s SOURCE TARGET ACTION  \
# 0                                    詩曰：混沌未分天地亂，茫茫渺渺無人見。
# 1                                       自從盤古破鴻濛，開闢從茲清濁辨。
# 2                                       覆載群生仰至仁，發明萬物皆成善。
# 3                                       欲知造化會元功，須看西遊釋厄傳。
# 4                                   蓋聞天地之數，有十二萬九千六百歲為一元。
# ...                                                  ...    ...    ...    ...
# 24341                                   五色梅時開時結，萬年桃時熟時新。
# 24342                                     千果千花爭秀，一天瑞靄紛紜。
# 24343                                            大眾合掌皈依。
# 24344  都念：「南無燃燈上古佛。南無藥師琉璃光王佛。南無釋迦牟尼佛。南無過去未來現在佛。南無清淨喜佛...
# 24345                                          「西遊記」至此終。
#
#        P/N
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 24341  NaN
# 24342  NaN
# 24343  NaN
# 24344  NaN
# 24345  NaN
#
# [24346 rows x 5 columns]

# %%
df_empty = df.loc[(df['SOURCE']=='') & (df['TARGET']=='') & (df['ACTION']=='')]

# %%
df_nonempty = df.loc[(df['SOURCE']!='') & (df['TARGET']!='') & (df['ACTION']!='')]

# %%
df_empty
# Out:
#                                                        s SOURCE TARGET ACTION  \
# 0                                    詩曰：混沌未分天地亂，茫茫渺渺無人見。
# 1                                       自從盤古破鴻濛，開闢從茲清濁辨。
# 2                                       覆載群生仰至仁，發明萬物皆成善。
# 3                                       欲知造化會元功，須看西遊釋厄傳。
# 4                                   蓋聞天地之數，有十二萬九千六百歲為一元。
# ...                                                  ...    ...    ...    ...
# 24341                                   五色梅時開時結，萬年桃時熟時新。
# 24342                                     千果千花爭秀，一天瑞靄紛紜。
# 24343                                            大眾合掌皈依。
# 24344  都念：「南無燃燈上古佛。南無藥師琉璃光王佛。南無釋迦牟尼佛。南無過去未來現在佛。南無清淨喜佛...
# 24345                                          「西遊記」至此終。
#
#        P/N
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 24341  NaN
# 24342  NaN
# 24343  NaN
# 24344  NaN
# 24345  NaN
#
# [15766 rows x 5 columns]

# %%
df_nonempty
# Out:
#                                                        s   SOURCE   TARGET  \
# 56     驚動高天上聖大慈仁者玉皇大天尊玄穹高上帝，駕座金闕雲宮靈霄寶殿，聚集仙卿，見有金光燄燄，即命...     玉皇大帝  千里眼、順風耳
# 59     須臾回報道：「臣奉旨觀聽金光之處，乃東勝神洲海東傲來小國之界，有一座花果山，山上有一仙石，石...  千里眼、順風耳     玉皇大帝
# 60                          玉帝垂賜恩慈曰：「下方之物，乃天地精華所生，不足為異。」     玉皇大帝  千里眼、順風耳
# 76                    連呼了三聲，忽見叢雜中跳出一個石猴，應聲高叫道：「我進去！我進去！」       石猴       眾猴
# 94          石猿喜不自勝，急抽身往外便走，復瞑目蹲身，跳出水外，打了兩個呵呵道：「大造化！大造化！」       石猴       眾猴
# ...                                                  ...      ...      ...
# 12273                                   那魔王把鎗尖點地，喝令小妖齊來。       魔王       小妖
# 12274                       那些潑怪，一個個拿刀弄杖，執劍輪鎗，把個孫大聖圍在中間。       小妖       行者
# 12275                          行者公然不懼，只叫：「來得好！來得好！正合吾意！」       行者       小妖
# 12276                                  使一條金箍棒，前迎後架，東攩西除。       小妖       行者
# 12281                             老魔王唏唏冷笑道：「那猴不要無禮！看手段！」       魔王       行者
#
#        ACTION P/N
# 56     開南天門觀看   P
# 59         回報   P
# 60          曰   P
# 76       應聲高叫   P
# 94          道   P
# ...       ...  ..
# 12273      喝令   P
# 12274       圍   N
# 12275       叫   P
# 12276    前迎後架   N
# 12281     冷笑道   P
#
# [6712 rows x 5 columns]

# %%
from sklearn.utils import resample, shuffle

# %%
# df_empty = resample(df_empty, n_samples=10000, random_state=42)

# %%
# df_res = pd.concat([df_empty, df_nonempty], axis=0)

# %%
df_res = shuffle(df_nonempty)

# %%
df_res
# Out:
#                                                       s SOURCE     TARGET  \
# 2133                                    張稍道：「我永世也不得翻江。」     張稍         李定
# 9911                                  沙僧攙著行者，一同到松林之下坐定。     沙僧         行者
# 4516                             三藏道：「也不敢用酒。酒是我僧家第一戒者。」     三藏         太公
# 4390              行者道：「不是這等說。今日我的父母，隔著牆，丟磚料瓦的，甚是打我罵我哩。」     行者          怪
# 3602  菩薩道：「那猴頭，專倚自強，那肯稱讚別人？今番前去，還有歸順的哩。若問時，先提起『取經』的字...     菩薩          龍
# ...                                                 ...    ...        ...
# 7337  那怪聞言，急傳號令，把那山前山後群妖，洞裏洞外諸怪，一齊點起，各執器械，把那三四層門，密密攔...     老妖         小妖
# 258                             猴王笑道：「好！好！好！自今就叫做孫悟空也！」    美猴王       菩提祖師
# 3294                  他把條鐵棒，捻一捻，依舊像個針兒，收在耳裏，背著行李，請師父上馬。    孫悟空         三藏
# 4474                           那怪道：「輕著些兒！你的手重，揪得我耳根子疼。」      怪         行者
# 1539  又命四大天師、九天仙女，大開玉京金闕、太玄寶宮、洞陽玉館，請如來高座七寶靈臺，調設各班坐位，...     玉帝  四大天師、九天仙女
#
#      ACTION P/N
# 2133      道   P
# 9911      攙   P
# 4516      道   P
# 4390      道   P
# 3602      道   P
# ...     ...  ..
# 7337    傳號令   P
# 258      笑道   P
# 3294      請   P
# 4474      道   P
# 1539      命   P
#
# [6712 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
df_res['desired_out'] = df_res.apply(lambda x: x['SOURCE']+':'+x['ACTION']+':'+x['TARGET'], axis=1)

# %%
def pn2score(s):
    if s == 'N':
        return -1
    elif s == 'P':
        return 1
    else:
        return 0
df_res['label'] = df_res['P/N'].apply(pn2score)

# %%
df_res = df_res.loc[:, ['s', 'desired_out', 'label']]

# %%
train, dev_test = train_test_split(df_res, test_size=0.4, train_size=0.6, random_state=42)
dev, test = train_test_split(dev_test, test_size=0.5, train_size=0.5, random_state=42)

# %%
train
# Out:
#                                                        s       desired_out  \
# 6763                             八戒當頭領路，沙僧後隨，出了那松林，上了大路。       八戒:領:沙僧、三藏
# 5256                                 豬八戒認得是木叉行者，引師父上前迎接。       八戒、三藏:迎接:惠岸
# 5281                                  叫：「悟空，取戒刀來，與他落了髮。」           三藏:道:行者
# 11737     沙僧道：「就行也不是話，再住也不是話。口說無憑，耳聞不如眼見。我背了馬，且請師父親去看看。」           沙僧:道:老者
# 4393   那怪道：「我雖是有些兒醜陋，若要俊，卻也不難。我一來時，曾與他講過，他願意方纔招我。今日怎麼...            怪:道:行者
# ...                                                  ...               ...
# 5324   八戒道：「哥啊，我聞得古人云：『龍能噴雲噯霧，播土揚沙；有巴山㨝嶺的手段，有翻江攪海的神通。...           八戒:道:行者
# 3798              三藏把行者扯住，悄悄的道：「徒弟，莫要與人鬭富。你我是單身在外，只恐有錯。」    三藏:扯住、悄悄的道:孫悟空
# 9327                       只見那本寺五百僧人，齊齊整整，吹打著細樂，都送出山門之外。  僧人:送:三藏、行者、八戒、沙僧
# 4956   老者道：「那風，能吹天地暗，善刮鬼神愁。裂石崩崖惡，吹人命即休。你們若遇著他那風吹了時，還想...           老者:道:行者
# 364              悟空伸手一摸，笑道：「師父沒成算！我雖少腮，卻比人多這個素袋，亦可准折過也。」       孫悟空:笑道:菩提祖師
#
#        label
# 6763       1
# 5256       1
# 5281       1
# 11737      1
# 4393       1
# ...      ...
# 5324       1
# 3798       1
# 9327       1
# 4956       1
# 364        1
#
# [4027 rows x 3 columns]

# %%
dev
# Out:
#                                                        s desired_out  label
# 546     那夜叉聽說，急轉水晶宮傳報道：「大王，外面有個花果山天生聖人孫悟空，口稱是大王緊鄰，將到宮也。」  夜叉:報道:東海龍王      1
# 9897                         沙僧道：「渾身都冷了，就有一點兒熱氣，怎的就得回生？」     沙僧:道:八戒      1
# 8769   長老便問：「陛下，你是那裏皇帝？何邦帝王？想必是國土不寧，讒臣欺虐，半夜逃生至此。有何話說，...     三藏:問:皇帝      1
# 7891                                        那怪又道：「拿孫行者。」    精細鬼:道:行者      1
# 11215                           沙僧道：「他有七十二般變化，就有七十二個頭哩。」     沙僧:道:八戒      1
# ...                                                  ...         ...    ...
# 3816                          三藏聽說，喫了一驚，埋怨行者道：「都是你！都是你！」  三藏:埋怨道:孙悟空     -1
# 8077                                      老怪問道：「你是那裏來的？」    女怪:問道:行者      1
# 3496                                  行者道：「放心，放心，等我去看來。」    孫悟空:道:三藏      1
# 9034                                           這行者保護了三藏。    行者:保護:三藏      1
# 4108   那院主慌忙跪下道：「老爺，我師父是人；只因那黑大王修成人道，常來寺裏與我師父講經，他傳了我師...     院主:道:三藏      1
#
# [1342 rows x 3 columns]

# %%
test
# Out:
#                                                        s        desired_out  \
# 4077                   茶罷，妖精欠身道：「適有小簡奉啟，後日一敘，何老友今日就下顧也？」         黑漢:欠身道:孫悟空
# 8657           老和尚道：「也莫要說壓，只道豎在天井裏，夜晚間走路，不記得啊，一頭也撞個大窟窿！」           老和尚:道:道人
# 3308                               行者撇了行李，走上前，叫聲「開門！開門！」          孫悟空:叫聲:老者
# 725     將近天門，金星高叫道：「那天門天將，大小吏兵，放開路者。此乃下界仙人，我奉玉帝聖旨，宣他來也。」  太白金星:高叫道:增長天王與眾天丁
# 11057          國王道：「國師差矣。那和尚乃禪教出身，必然先會禪機，纔敢奉旨求經；你怎與他賭此？」          國王:道:虎力大仙
# ...                                                  ...                ...
# 5539                                         行者遂領師父上了大路。           行者:遂領:三藏
# 5475                                     獃子依言，接了手帕，頂在頭上。            八戒:接:婦人
# 10280  對行者道：「悟空，這妖精已是降了，卻只是野心不定，等我教他一步一拜，只拜到落伽山，方纔收法。...            菩薩:道:行者
# 9028                                     眾神依言，收了陰風，擺在左右。        山神、土地:依言:行者
# 11191                           虎力道：「陛下，正要他如此，方纔出得我們之氣。」          虎力大仙:道:國王
#
#        label
# 4077       1
# 8657       1
# 3308       1
# 725        1
# 11057      1
# ...      ...
# 5539       1
# 5475       1
# 10280      1
# 9028       1
# 11191      1
#
# [1343 rows x 3 columns]

# %%
train.to_csv('./train.csv', index=False)
test.to_csv('./test.csv', index=False)
dev.to_csv('./validate.csv', index=False)
