# %%
import pandas as pd

# %%
df = pd.read_excel('Xiyouji_Masterfile_20220103_HYJ tags.xlsx')
df
# Out:
#       title     n            chaptitle  \
# 0       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# 1       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# 2       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# 3       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# 4       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# ...     ...   ...                  ...
# 24341   西遊記  第一百回       第一百回　徑回東土　五聖成真
# 24342   西遊記  第一百回       第一百回　徑回東土　五聖成真
# 24343   西遊記  第一百回       第一百回　徑回東土　五聖成真
# 24344   西遊記  第一百回       第一百回　徑回東土　五聖成真
# 24345   西遊記  第一百回       第一百回　徑回東土　五聖成真
#
#                                                        s     sn SOURCE TARGET  \
# 0                                    詩曰：混沌未分天地亂，茫茫渺渺無人見。      1    NaN    NaN
# 1                                       自從盤古破鴻濛，開闢從茲清濁辨。      2    NaN    NaN
# 2                                       覆載群生仰至仁，發明萬物皆成善。      3    NaN    NaN
# 3                                       欲知造化會元功，須看西遊釋厄傳。      4    NaN    NaN
# 4                                   蓋聞天地之數，有十二萬九千六百歲為一元。      5    NaN    NaN
# ...                                                  ...    ...    ...    ...
# 24341                                   五色梅時開時結，萬年桃時熟時新。  23296    NaN    NaN
# 24342                                     千果千花爭秀，一天瑞靄紛紜。  23297    NaN    NaN
# 24343                                            大眾合掌皈依。  23298    NaN    NaN
# 24344  都念：「南無燃燈上古佛。南無藥師琉璃光王佛。南無釋迦牟尼佛。南無過去未來現在佛。南無清淨喜佛...  23299    NaN    NaN
# 24345                                          「西遊記」至此終。  23300    NaN    NaN
#
#       ACTION  P/N COMMENTS QUESTIONS?  Unnamed: 11
# 0        NaN  NaN      NaN        NaN          NaN
# 1        NaN  NaN      NaN        NaN          NaN
# 2        NaN  NaN      NaN        NaN          NaN
# 3        NaN  NaN      NaN        NaN          NaN
# 4        NaN  NaN      NaN        NaN          NaN
# ...      ...  ...      ...        ...          ...
# 24341    NaN  NaN      NaN        NaN          NaN
# 24342    NaN  NaN      NaN        NaN          NaN
# 24343    NaN  NaN      NaN        NaN          NaN
# 24344    NaN  NaN      NaN        NaN          NaN
# 24345    NaN  NaN      NaN        NaN          NaN
#
# [24346 rows x 12 columns]

# %%
df.drop('Unnamed: 11', axis=1, inplace=True)

# %%
df = df.loc[:, ['s', 'SOURCE', 'TARGET', 'ACTION', 'P/N']]

# %%
df['SOURCE'] = df['SOURCE'].apply(lambda x: '' if pd.isna(x) else x)

# %%
df['TARGET'] = df['TARGET'].apply(lambda x: '' if pd.isna(x) else x)

# %%
df['ACTION'] = df['ACTION'].apply(lambda x: '' if pd.isna(x) else x)

# %%
df
# Out:
#                                                        s SOURCE TARGET ACTION  \
# 0                                    詩曰：混沌未分天地亂，茫茫渺渺無人見。
# 1                                       自從盤古破鴻濛，開闢從茲清濁辨。
# 2                                       覆載群生仰至仁，發明萬物皆成善。
# 3                                       欲知造化會元功，須看西遊釋厄傳。
# 4                                   蓋聞天地之數，有十二萬九千六百歲為一元。
# ...                                                  ...    ...    ...    ...
# 24341                                   五色梅時開時結，萬年桃時熟時新。
# 24342                                     千果千花爭秀，一天瑞靄紛紜。
# 24343                                            大眾合掌皈依。
# 24344  都念：「南無燃燈上古佛。南無藥師琉璃光王佛。南無釋迦牟尼佛。南無過去未來現在佛。南無清淨喜佛...
# 24345                                          「西遊記」至此終。
#
#        P/N
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 24341  NaN
# 24342  NaN
# 24343  NaN
# 24344  NaN
# 24345  NaN
#
# [24346 rows x 5 columns]

# %%
df_empty = df.loc[(df['SOURCE']=='') & (df['TARGET']=='') & (df['ACTION']=='')]

# %%
df_nonempty = df.loc[(df['SOURCE']!='') & (df['TARGET']!='') & (df['ACTION']!='')]

# %%
from sklearn.utils import resample, shuffle

# %%
# df_empty = resample(df_empty, n_samples=10000, random_state=42)

# %%
# df_res = pd.concat([df_empty, df_nonempty], axis=0)

# %%
df_res = shuffle(df_nonempty)

# %%
df_res
# Out:
#                                                        s   SOURCE TARGET  \
# 11164                                       行者道：「你怎麼定得？」       行者     三藏
# 10651                           嗔道：「那老賊憊𢤿，把我的元身都說與這夥凡人！」       行者     眾僧
# 7124                                    他又思量道：「認得就好說話了。」       八戒     行者
# 1112   即差四大天王，協同李天王並哪吒太子，點二十八宿、九曜星官、十二元辰、五方揭諦、四值功曹、東西...       玉帝   十二元辰
# 3327      行者道：「還是我重子重孫哩！我那生身的年紀，我不記得是幾時；但只在這山腳下，已五百餘年了。」      孫悟空     老者
# ...                                                  ...      ...    ...
# 4677                           三藏復問道：「老施主，始初說西天經難取者，何也？」       三藏     老者
# 10629                                那道士迎著道：「先生，那一位是令親？」       道士     行者
# 1137                               上下佈了十八架天羅地網，先差九曜惡星出戰。      李天王    九曜星
# 6233                              慌得那三星與鎮元子共三藏師徒，一齊迎出寶殿。  鎮元大仙、三老     菩薩
# 59     須臾回報道：「臣奉旨觀聽金光之處，乃東勝神洲海東傲來小國之界，有一座花果山，山上有一仙石，石...  千里眼、順風耳   玉皇大帝
#
#       ACTION P/N
# 11164      道   P
# 10651      道   P
# 7124       道   P
# 1112       差   P
# 3327       道   P
# ...      ...  ..
# 4677      問道   P
# 10629      道   P
# 1137       差   P
# 6233       迎   P
# 59        回報   P
#
# [6712 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
df_res['desired_out'] = df_res.apply(lambda x: x['SOURCE']+':'+x['ACTION']+':'+x['TARGET'], axis=1)

# %%
# def pn2score(s):
#     if s == 'N':
#         return -1
#     elif s == 'P':
#         return 1
#     else:
#         return 0
# df_res['label'] = df_res['P/N'].apply(pn2score)

# %%
df_res = df_res.loc[:, ['s', 'desired_out']]

# %%
train, dev = train_test_split(df_res, test_size=0.4, train_size=0.6, random_state=42)

# %%
test = shuffle(pd.DataFrame(df['s']))

# %%
test['desired_out'] = ''

# %%
train
# Out:
#                                                        s  desired_out
# 676                                              眾猴磕頭禮謝。  眾猴:磕頭禮謝:孫悟空
# 376                                  悟空道：「怎麼為『朝遊北海暮蒼梧』？」   孫悟空:道:菩提祖師
# 9238                               行者罵道：「你這獃孽畜，攛道師父咒我哩！」     行者:罵道:八戒
# 3812                                    三藏教：「掌上燈來，讓你再看。」      三藏:教:老僧
# 6069                          福星道：「是甚地方？因何阻滯？乞為明示，吾好裁處。」      福星:道:行者
# ...                                                  ...          ...
# 1512              那大聖收了如意棒，抖擻神威，將身一縱，站在佛祖手心裏，卻道聲：「我出去也！」   孫悟空:道:如來佛祖
# 8837                                     三藏回入裏面道：「是那三樁？」      三藏:道:八戒
# 10612  眾僧道：「只因呼風喚雨，三個仙長來此處，滅了我等；哄信君王，把我們寺拆了，度牒追了，不放歸鄉...      眾僧:道:行者
# 127                                       猴王道：「此三者居於何所？」   美猴王:道:通背猿猴
# 3343   行者又有眼色：見師父洗浴，脫下一件白布短小直裰未穿，他即扯過來披在身上，卻將那虎皮脫下，聯接...     孫悟空:道:老者
#
# [4027 rows x 2 columns]

# %%
dev
# Out:
#                                                        s  desired_out
# 6160                                      帝君道：「何事？自當領教。」      帝君:道:行者
# 8189                                  二魔道：「孫行者。你來看，你來看。」      銀角:道:金角
# 3007                                魔王喝令綁了，眾妖一齊將三人用繩索綁縛。  眾妖:綁縛:三藏、從者
# 594                                          悟空道：「令弟何在？」   孫悟空:道:東海龍王
# 2432                         太宗出森羅殿，又起手問十王道：「朕宮中老少安否如何？」  唐王 :問道:十代閻王
# ...                                                  ...          ...
# 12150                                   三藏道：「悟能，憑你怎麼處治。」      三藏:道:八戒
# 480    約有三五十個，都含淚道：「我等因大王修仙去後，這兩年被他爭吵，把我們都攝將來，那不是我們洞中...     眾猴:道:孫悟空
# 6436           他把棍藏在身邊，走上前，迎著怪物，叫聲：「老官兒，往那裏去？怎麼又走路，又念經？」      行者:叫:妖精
# 12241                那洞中大小群妖，一個個精神抖擻，即忙抬出一根丈二長的點鋼鎗，遞與老怪。     小妖:遞與:魔王
# 5198                       八戒舉鈀架住道：「你是個甚麼『哭喪杖』，斷叫你祖宗看杖！」    八戒:架住道:妖精
#
# [2685 rows x 2 columns]

# %%
test
# Out:
#                                                        s desired_out
# 9018                           行者道：「這甚打緊？你肯早說時，卻不尋下些等你。」
# 14487  行者道：「你這獃子，全不知事！那時節用心防備，故此不傷；今日只為搧息火光，不曾捻避火訣，又未...
# 7989                       伶俐蟲道：「不管那裏走罷。若回去說沒寶貝，斷然是送命了。」
# 12518                               這纔是：魔頭驕傲無防備，主杖還歸與本人。
# 14412                            行者道：「利害！利害！我師父卻怎生得度那方？」
# ...                                                  ...         ...
# 9572                                          這番卻不上半里之地。
# 968        那土地連忙施禮，即呼那一班鋤樹力士、運水力士、修桃力士、打掃力士都來見大聖磕頭，引他進去。
# 3199                                             三藏歡喜收納。
# 3055               三藏不勝感激，將包袱捎在馬上，牽著韁繩，相隨老叟徑出了坑坎之中，走上大路。
# 15637  又有兩個黃衣女童，捧一個紅漆丹盤，盤內有六個細磁茶盂，盂內設幾品異果，橫擔著匙兒，提一把白鐵...
#
# [24346 rows x 2 columns]

# %%
train.to_csv('./train.csv', index=False)
test.to_csv('./test.csv', index=False)
dev.to_csv('./validate.csv', index=False)
