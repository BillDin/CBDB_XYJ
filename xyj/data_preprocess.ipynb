# %%
import pandas as pd

# %%
df = pd.read_excel('Xiyouji_Masterfile_20220103_HYJ tags.xlsx')
df
# Out:
#       title     n            chaptitle  \
# 0       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# 1       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# 2       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# 3       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# 4       西遊記   第一回  第一回　靈根育孕源流出　心性修持大道生
# ...     ...   ...                  ...
# 24341   西遊記  第一百回       第一百回　徑回東土　五聖成真
# 24342   西遊記  第一百回       第一百回　徑回東土　五聖成真
# 24343   西遊記  第一百回       第一百回　徑回東土　五聖成真
# 24344   西遊記  第一百回       第一百回　徑回東土　五聖成真
# 24345   西遊記  第一百回       第一百回　徑回東土　五聖成真
#
#                                                        s     sn SOURCE TARGET  \
# 0                                    詩曰：混沌未分天地亂，茫茫渺渺無人見。      1    NaN    NaN
# 1                                       自從盤古破鴻濛，開闢從茲清濁辨。      2    NaN    NaN
# 2                                       覆載群生仰至仁，發明萬物皆成善。      3    NaN    NaN
# 3                                       欲知造化會元功，須看西遊釋厄傳。      4    NaN    NaN
# 4                                   蓋聞天地之數，有十二萬九千六百歲為一元。      5    NaN    NaN
# ...                                                  ...    ...    ...    ...
# 24341                                   五色梅時開時結，萬年桃時熟時新。  23296    NaN    NaN
# 24342                                     千果千花爭秀，一天瑞靄紛紜。  23297    NaN    NaN
# 24343                                            大眾合掌皈依。  23298    NaN    NaN
# 24344  都念：「南無燃燈上古佛。南無藥師琉璃光王佛。南無釋迦牟尼佛。南無過去未來現在佛。南無清淨喜佛...  23299    NaN    NaN
# 24345                                          「西遊記」至此終。  23300    NaN    NaN
#
#       ACTION  P/N COMMENTS QUESTIONS?  Unnamed: 11
# 0        NaN  NaN      NaN        NaN          NaN
# 1        NaN  NaN      NaN        NaN          NaN
# 2        NaN  NaN      NaN        NaN          NaN
# 3        NaN  NaN      NaN        NaN          NaN
# 4        NaN  NaN      NaN        NaN          NaN
# ...      ...  ...      ...        ...          ...
# 24341    NaN  NaN      NaN        NaN          NaN
# 24342    NaN  NaN      NaN        NaN          NaN
# 24343    NaN  NaN      NaN        NaN          NaN
# 24344    NaN  NaN      NaN        NaN          NaN
# 24345    NaN  NaN      NaN        NaN          NaN
#
# [24346 rows x 12 columns]

# %%
df.drop('Unnamed: 11', axis=1, inplace=True)

# %%
df = df.loc[:, ['s', 'SOURCE', 'TARGET', 'ACTION', 'P/N']]

# %%
df['SOURCE'] = df['SOURCE'].apply(lambda x: '' if pd.isna(x) else x)

# %%
df['TARGET'] = df['TARGET'].apply(lambda x: '' if pd.isna(x) else x)

# %%
df['ACTION'] = df['ACTION'].apply(lambda x: '' if pd.isna(x) else x)

# %%
df
# Out:
#                                                        s SOURCE TARGET ACTION  \
# 0                                    詩曰：混沌未分天地亂，茫茫渺渺無人見。
# 1                                       自從盤古破鴻濛，開闢從茲清濁辨。
# 2                                       覆載群生仰至仁，發明萬物皆成善。
# 3                                       欲知造化會元功，須看西遊釋厄傳。
# 4                                   蓋聞天地之數，有十二萬九千六百歲為一元。
# ...                                                  ...    ...    ...    ...
# 24341                                   五色梅時開時結，萬年桃時熟時新。
# 24342                                     千果千花爭秀，一天瑞靄紛紜。
# 24343                                            大眾合掌皈依。
# 24344  都念：「南無燃燈上古佛。南無藥師琉璃光王佛。南無釋迦牟尼佛。南無過去未來現在佛。南無清淨喜佛...
# 24345                                          「西遊記」至此終。
#
#        P/N
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 24341  NaN
# 24342  NaN
# 24343  NaN
# 24344  NaN
# 24345  NaN
#
# [24346 rows x 5 columns]

# %%
df_empty = df.loc[(df['SOURCE']=='') & (df['TARGET']=='') & (df['ACTION']=='')]

# %%
df_nonempty = df.loc[(df['SOURCE']!='') & (df['TARGET']!='') & (df['ACTION']!='')]

# %%
from sklearn.utils import resample, shuffle

# %%
# df_empty = resample(df_empty, n_samples=10000, random_state=42)

# %%
# df_res = pd.concat([df_empty, df_nonempty], axis=0)

# %%
df_res = shuffle(df_nonempty)

# %%
df_res
# Out:
#                                                        s SOURCE   TARGET  \
# 4016                   那裏面有把門的小妖，開了門出來，問道：「你是何人，敢來擊吾仙洞？」     小妖      孫悟空
# 8156                             此時大聖已在雲端裏，聞得叫他名字，急回頭觀看。     行者       銀角
# 8052                                      卻拖著腳，藏在路旁深草科裏。     行者  巴山虎、倚海龍
# 5832                      三藏僧：「徒弟，不可傷他性命；不然，又一個得財傷人的罪了。」     三藏       行者
# 11796                 八戒道：「這河忒也凍得結實，地凌響了。或者這半中間連底通錮住了也。」     八戒       三藏
# ...                                                  ...    ...      ...
# 4443                     行者道：「我纔試他一試耍子。此去一定拿來與你們看。且莫憂愁。」     行者       三藏
# 6742   被公主扯住道：「前門裏你出不去！那些大小妖精，都在門外搖旗吶喊，擂鼓篩鑼；助著大王，與你徒弟...     公主       三藏
# 3334                              行者道：「師父，你是唐姓，怎的和他是華宗？」    孫悟空       三藏
# 4644                行者道：「你兒子便是熟嘴！我這些時，只因跟我師父走路辛苦，還懶說話哩。」     行者       老者
# 1227                    天王道：「孩兒，你隨菩薩修行這幾年，想必也有些神通，切須在意。」    李天王       行者
#
#       ACTION P/N
# 4016      問道   P
# 8156       看   P
# 8052       藏   N
# 5832       的   P
# 11796      道   P
# ...      ...  ..
# 4443       道   P
# 6742     扯住道   P
# 3334       道   P
# 4644       道   P
# 1227       道   P
#
# [6712 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
df_res['desired_out'] = df_res.apply(lambda x: x['SOURCE']+':'+x['ACTION']+':'+x['TARGET'], axis=1)

# %%
# def pn2score(s):
#     if s == 'N':
#         return -1
#     elif s == 'P':
#         return 1
#     else:
#         return 0
# df_res['label'] = df_res['P/N'].apply(pn2score)

# %%
df_res = df_res.loc[:, ['s', 'desired_out']]

# %%
train, dev = train_test_split(df_res, test_size=0.4, train_size=0.6, random_state=42)

# %%
test = pd.DataFrame(df['s'])

# %%
test['desired_out'] = 'N/A'

# %%
train
# Out:
#                                                        s      desired_out
# 6350                                      八戒道：「師父，這不到了？」          八戒:道:三藏
# 5648   三藏道：「胡說！胡說！他那父母懷胎，不知受了多少苦楚，方生下來。未及三日，怎麼就把他拿來當果子？」          三藏:道:明月
# 10337                                 行者道：「我等容易，只是師父難哩。」          行者:道:沙僧
# 6104                 八戒又笑道：「既不是人家奴才，來道叫做『添壽』、『添福』、『添祿』？」         八戒:笑道:福星
# 962                 玉帝道：「朕見你身閑無事，與你件執事。你且權管那蟠桃園，早晚好生在意。」       玉皇大帝:道:孫悟空
# ...                                                  ...              ...
# 7331                                        妖怪道：「我何嘗罵你？」          老妖:道:行者
# 5668       行者道：「這獃子笑話我老孫。老孫五百年前，因訪仙道時，也曾雲遊在海角天涯。那般兒不曾見？」          行者:道:八戒
# 9322   行者道：「不要你去西天。我內中有個緣故。你只挑得四十里進城。待捉了妖精，你還做你的皇帝，我們...          行者:道:皇帝
# 8025                                           ——「卻要仔細。」  金角、銀角:道:巴山虎、倚海龍
# 9463                      行者道：「既如此，收了去罷。若不是菩薩親來，決不饒他性命。」          行者:道:八戒
#
# [4027 rows x 2 columns]

# %%
dev
# Out:
#                                                        s         desired_out
# 11316               行者下來，與三藏、八戒、沙僧立在殿前，見那道士在滾油鍋裏打掙，爬不出來。           三藏:見:羊力大仙
# 8439                           他三人脫得災危，謝了行者，卻問：「妖魔那裏去了？」       三藏、八戒、沙僧:問:行者
# 9632               猴王發怒，抓過他來，往那路旁邊賴石頭上滑辣的一摜，將屍骸摜得像個肉餅一般。             行者:摜:妖精
# 696                                      玉帝道：「那路神將下界收伏？」         玉皇大帝:道:文武仙卿
# 11446  前面坐的老者，急起身迎到屏門後道：「哥哥莫嚷，不是邪魔，乃東土大唐取經的羅漢。徒弟們相貌雖兇...             老者:道:老者
# ...                                                  ...                 ...
# 4725            八戒道：「哥啊，你不曾聞得『避色如避讐，避風如避箭』哩！我們躲一躲，也不虧人。」             八戒:道:行者
# 10177          教他：「捏著拳頭，快去與那妖精索戰，許敗不許勝。敗將來我這跟前，我自有法力收他。」             菩薩:教:行者
# 6249    菩薩將楊柳枝，蘸出瓶中甘露，把行者手心裏畫了一道起死回生的符字，教他放在樹根之下，但看水出為度。             菩薩:畫:行者
# 2394                    幸有崔判官喚一青面獠牙鬼使，喝退了建成、元吉，太宗方得脫身而去。         崔玨:喝退:建成、元吉
# 957    與那九曜星、五方將、二十八宿、四大天王、十二元辰、五方五老、普天星相、河漢群神，俱只以弟兄相...  孫悟空:弟兄相待、彼此稱呼:河漢群神
#
# [2685 rows x 2 columns]

# %%
test
# Out:
#                                                        s desired_out
# 0                                    詩曰：混沌未分天地亂，茫茫渺渺無人見。         N/A
# 1                                       自從盤古破鴻濛，開闢從茲清濁辨。         N/A
# 2                                       覆載群生仰至仁，發明萬物皆成善。         N/A
# 3                                       欲知造化會元功，須看西遊釋厄傳。         N/A
# 4                                   蓋聞天地之數，有十二萬九千六百歲為一元。         N/A
# ...                                                  ...         ...
# 24341                                   五色梅時開時結，萬年桃時熟時新。         N/A
# 24342                                     千果千花爭秀，一天瑞靄紛紜。         N/A
# 24343                                            大眾合掌皈依。         N/A
# 24344  都念：「南無燃燈上古佛。南無藥師琉璃光王佛。南無釋迦牟尼佛。南無過去未來現在佛。南無清淨喜佛...         N/A
# 24345                                          「西遊記」至此終。         N/A
#
# [24346 rows x 2 columns]

# %%
train.to_csv('./train.csv', index=False)
test.to_csv('./test.csv', index=False)
dev.to_csv('./validate.csv', index=False)
